# %%
from skimage.color import rgb2lab 
from skimage.color import rgb2hsv
from skimage.color import rgb2grey
from numpy import concatenate
from skimage.io import imread
import numpy as np
from numpy import reshape
from skimage import io
rgbimg=imread("D://Lokin//Data Analytics//TOMTOM//Images//HOG feature descriptor images//119.jpg")
labimg=rgb2lab(rgbimg)
hsvimg=rgb2hsv(rgbimg)
# labimg=labimg.ravel()
# hsvimg=hsvimg.ravel()
labimg_1=reshape(labimg,(1, 19660800),order='C')
print(labimg_1)
hsvimg_1=reshape(hsvimg,(1, 19660800),order='C')
print(hsvimg_1)
a=concatenate((labimg_1,hsvimg_1),axis=0.88)
print(a)
# Out:
# [[ 37.46295927   1.8902352  -11.78480355 ...,  41.32156017   3.61365772
#    -7.06419334]]
# [[ 0.62179487  0.24299065  0.41960784 ...,  0.69230769  0.11926606
#    0.42745098]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-02e46786828d> in <module>()
#      16 hsvimg_1=reshape(hsvimg,(1, 19660800),order='C')
#      17 print(hsvimg_1)
# ---> 18 a=concatenate((labimg_1,hsvimg_1),axis=0.88)
#      19 print(a)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
a
# Out:
# array([[ 37.46295927,   1.8902352 , -11.78480355, ...,   0.69230769,
#           0.11926606,   0.42745098]])

# %%
from matplotlib import pyplot as plt
from skimage.io import imsave
plt.imshow(labimg)
plt.show()
plt.imshow(hsvimg)
plt.show()
labimg=labimg.astype('int64')
hsvimg=hsvimg.astype('int64')
imsave("lab_119.jpg",labimg)
imsave("hsv_119.jpg",hsvimg)
# Out:
# C:\Users\Lokin\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from int64 to float64
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\Lokin\Anaconda3\lib\site-packages\skimage\io\_io.py:132: UserWarning: lab_119.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Lokin\Anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type int64 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\Lokin\Anaconda3\lib\site-packages\skimage\util\dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 68 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# C:\Users\Lokin\Anaconda3\lib\site-packages\skimage\io\_io.py:132: UserWarning: hsv_119.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ...

# %%
print(labimg)
# Out:
# [[[ 37   1 -11]
#   [ 39   1 -11]
#   [ 40   1 -11]
#   ...,
#   [ 52   3  -1]
#   [ 52   3  -1]
#   [ 52   3  -1]]
#
#  [[ 36   1 -11]
#   [ 38   1 -11]
#   [ 39   1 -11]
#   ...,
#   [ 52   4  -2]
#   [ 51   3  -1]
#   [ 51   3  -1]]
#
#  [[ 35   1 -11]
#   [ 37   1 -11]
#   [ 39   1 -11]
#   ...,
#   [ 52   4  -2]
#   [ 52   4  -2]
#   [ 51   4  -2]]
#
#  ...,
#  [[ 45   7  -6]
#   [ 45   7  -6]
#   [ 45   7  -6]
#   ...,
#   [ 40   3  -7]
#   [ 39   3  -7]
#   [ 38   3  -7]]
#
#  [[ 45   7  -6]
#   [ 45   7  -6]
#   [ 45   7  -6]
#   ...,
#   [ 41   3  -7]
#   [ 40   3  -7]
#   [ 40   3  -7]]
#
#  [[ 45   7  -6]
#   [ 45   7  -6]
#   [ 46   7  -6]
#   ...,
#   [ 42   3  -7]
#   [ 41   3  -7]
#   [ 41   3  -7]]]
